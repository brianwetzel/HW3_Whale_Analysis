# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path
import seaborn as sns

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_data = Path("Resources/whale_returns.csv")
whale_df = pd.read_csv(whale_data, index_col="Date", infer_datetime_format=True, parse_dates=True)

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df = whale_df.dropna()

# %%
# Checking if Nulls were properly dropped: yes, it did
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_data = Path("Resources/algo_returns.csv")
algo_df = pd.read_csv(algo_data, index_col="Date", infer_datetime_format=True, parse_dates=True)

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df = algo_df.dropna()

# %%
# Checking if Nulls were properly dropped: yes, it did
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    0
# dtype: int64

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_data = Path("Resources/sp500_history.csv")
sp500_df = pd.read_csv(sp500_data, index_col="Date", infer_datetime_format=True, parse_dates=True)

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types

# Removed the dollar signs, commas, and any spaces.  Then converted the remaining object to an integer.
sp500_df["Close"] = sp500_df["Close"].replace('[\$\,\.]',"",regex=True).astype(int)

# Re-run dtypes to see that it worked: yes, it did
sp500_df.dtypes
# Out:
# Close    int64
# dtype: object

# %%
# Sort by index to have dataframe in correct time order

sp500_df.sort_index(ascending=True, inplace=True)
sp500_df.head()
# Out:
#              Close
# Date
# 2012-10-01  144449
# 2012-10-02  144575
# 2012-10-03  145099
# 2012-10-04  146140
# 2012-10-05  146093

# %%
# Calculate Daily Returns

sp500_returns = sp500_df.pct_change()
sp500_returns.head()
# Out:
#                Close
# Date
# 2012-10-01       NaN
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322

# %%
# Drop nulls

sp500_returns = sp500_returns.dropna()
sp500_returns.head()
# Out:
#                Close
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %%
# Rename `Close` Column to be specific to this portfolio.

sp500_returns = sp500_returns.rename(columns={'Close': 'S&P 500'})
sp500_returns.head()
# Out:
#              S&P 500
# Date
# 2012-10-02  0.000872
# 2012-10-03  0.003624
# 2012-10-04  0.007174
# 2012-10-05 -0.000322
# 2012-10-08 -0.003457

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.

combined_returns = pd.concat([whale_df, algo_df, sp500_returns], axis='columns', join='inner')
combined_returns.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2   S&P 500
# Date
# 2015-03-03 -0.000949 -0.004539
# 2015-03-04  0.002416 -0.004389
# 2015-03-05  0.004323  0.001196
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios

combined_returns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios

cumulative_returns = (1 + combined_returns).cumprod()

# Plot cumulative returns

cumulative_returns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk

combined_returns.boxplot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios

combined_std = combined_returns.std()
combined_std = combined_std.sort_values(ascending=False)
combined_std.head(10)

# Determine which portfolios are riskier than the S&P 500

# BERKSHIRE HATHAWAY INC & TIGER GLOBAL MANAGEMENT LLC are riskier than the S&P 500
# Out:
# BERKSHIRE HATHAWAY INC         0.012919
# TIGER GLOBAL MANAGEMENT LLC    0.010894
# S&P 500                        0.008554
# Algo 2                         0.008342
# SOROS FUND MANAGEMENT LLC      0.007895
# Algo 1                         0.007620
# PAULSON & CO.INC.              0.007023
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500

sp500_std = combined_returns["S&P 500"].std()
print(f"S&P 500 Standard Deviation: {sp500_std}")

# Determine which portfolios are riskier than the S&P 500

# BERKSHIRE HATHAWAY INC & TIGER GLOBAL MANAGEMENT LLC are riskier than the S&P 500
# Out:
# S&P 500 Standard Deviation: 0.008553731597758199

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)

annualized_std = combined_std * np.sqrt(252)
annualized_std = annualized_std.sort_values(ascending=False)
annualized_std.head(10)

# BERKSHIRE HATHAWAY INC & TIGER GLOBAL MANAGEMENT LLC are riskier than the S&P 500
# Out:
# BERKSHIRE HATHAWAY INC         0.205077
# TIGER GLOBAL MANAGEMENT LLC    0.172936
# S&P 500                        0.135786
# Algo 2                         0.132430
# SOROS FUND MANAGEMENT LLC      0.125335
# Algo 1                         0.120967
# PAULSON & CO.INC.              0.111488
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window

combined_returns.rolling(window=21).std().plot(figsize=(20,10))

# Plot the rolling standard deviation
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation

correlation = combined_returns.corr()


# Display de correlation matrix

correlation.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_5a755_row0_col0, #T_5a755_row1_col1, #T_5a755_row2_col2, #T_5a755_row3_col3, #T_5a755_row4_col4, #T_5a755_row5_col5, #T_5a755_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_5a755_row0_col1 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_5a755_row0_col2 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_5a755_row0_col3, #T_5a755_row3_col6 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_5a755_row0_col4 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_5a755_row0_col5 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_5a755_row0_col6 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_5a755_row1_col0 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_5a755_row1_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_5a755_row1_col3 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_5a755_row1_col4 {
#   background-color: #6282ea;
# ...

# %%
# Display de correlation matrix: 
# Correlation scatter plot comparing Algo 2 vs. S&P 500
# We can see a high correlation

combined_returns.plot(kind="scatter", y = "Algo 2", x = "S&P 500", figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='S&P 500', ylabel='Algo 2'>

# %%
# Portfolios Algo 2 and Soros Fund have the highest correlation to the S&P 500

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Plot beta trend

# 60-day rolling covariance of Algo 1 vs. S&P 500
rolling_covariance_algo1 = combined_returns['Algo 1'].rolling(window=60).cov(combined_returns['S&P 500'])


# 60-day rolling variance of S&P 500
rolling_variance_sp500 = combined_returns['S&P 500'].rolling(window=60).var()


# 60-day rolling beta of Soros Fund and plot the data
rolling_beta_algo1 = rolling_covariance_algo1 / rolling_variance_sp500

# Plot the 60-day rolling trend
rolling_beta_algo1.plot(figsize=(20, 10), title='Rolling 60-Day Covariance of Algo 1 vs. S&P 500 Returns')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Covariance of Algo 1 vs. S&P 500 Returns'}, xlabel='Date'>

# %%
# Calculate covariance of a Algo 1 portfolio
covariance_algo1 = combined_returns['Algo 1'].cov(combined_returns['S&P 500'])

# Calculate variance of S&P 500
variance_sp500 = combined_returns['S&P 500'].var()

# Computing beta
algo1_beta = covariance_algo1 / variance_sp500
print(f"Algo 1 Beta VS S&P 500: {algo1_beta}")

#--------------------

# Calculate covariance of a Algo 2 portfolio
covariance_algo2 = combined_returns['Algo 2'].cov(combined_returns['S&P 500'])

# Calculate variance of S&P 500
variance_sp500 = combined_returns['S&P 500'].var()

# Computing beta
algo2_beta = covariance_algo2 / variance_sp500
print(f"Algo 2 Beta VS S&P 500: {algo2_beta}")
# Out:
# Algo 1 Beta VS S&P 500: 0.24899091459425693
# Algo 2 Beta VS S&P 500: 0.837534540275776

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half-life.

# %%
# Use `ewm` to calculate the rolling window

# DataFrame.ewm(com=None, span=None, halflife=None, alpha=None, min_periods=0, adjust=True, ignore_na=False, axis=0, times=None)

# Calculate
EWMA_combined_returns = combined_returns.ewm(halflife=21).mean()

# Plot
EWMA_combined_returns.plot(figsize=(20,10))


# combined_df_ewm = combined_df.ewm(span = 21,adjust = False).mean()
# (1+combined_df_ewm).cumprod().plot(figsize = (18,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Annualized Sharpe Ratios

# Assuming a risk free rate of 0.00022% daily, drawn from csv data in a prior activity.
risk_free_rate = 0.0000022

combined_sharpe_ratios = ((combined_returns.mean()-(risk_free_rate)) * 252) / (combined_returns.std() * np.sqrt(252))

# %%
# Visualize the sharpe ratios as a bar plot

combined_sharpe_ratios.plot(kind = "bar", title = "Sharpe Ratios", figsize = (20,10))
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.

# %% [markdown]
# <b>Algo 1 Portfolio Analysis:</b><br>
# Algo 1 is a great portfolio which did outperform the S&P 500 because:
# * Higest cumulative return among all the portfolios
# * 2nd lowest standard deviation which implies that its low risk
# * Low correlation to other portfolios, generally regarded as a positive
# * Low beta of .249, so it has a low sensativity to market movements
# * High sharpe ratio indicates a high reward to risk ratio per unit of volitility.
#
# <b>Algo 2 Portfolio Analysis:</b><br>
# Algo 2 is an average portfolio which did not outperform the S&P 500 because:
# * Middle of the pack (4th) cumulative return among all the portfolios, but lower than S&P 500
# * Middle of the pack (4th) standard deviation which implies that its medium risk, but slightly lower risk than S&P 500
# * High correlation to other portfolios, which is generally a regarded as a negative quality
# * Medium beta of .838, so it has a medium sensativity to market movements
# * Middle of the pack (4th) sharpe ratio indicates an average reward to risk ratio per unit of volitility, but slightly lower than S&P500

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
#
# For this demo solution, we fetch data from three companies listes in the S&P 500 index.
#
# * `GOOG` - [Google, LLC](https://en.wikipedia.org/wiki/Google)
#
# * `AAPL` - [Apple Inc.](https://en.wikipedia.org/wiki/Apple_Inc.)
#
# * `COST` - [Costco Wholesale Corporation](https://en.wikipedia.org/wiki/Costco)

# %%
# Reading data from 1st stock

jpm_data = Path("Resources/jpm_historical.csv")
jpm_df = pd.read_csv(jpm_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
jpm_df.head()
# Out:
#             Close
# Date
# 2015-03-03  61.97
# 2015-03-04  62.13
# 2015-03-05  62.00
# 2015-03-06  60.89
# 2015-03-09  61.50

# %%
# Reading data from 2nd stock

visa_data = Path("Resources/visa_historical.csv")
visa_df = pd.read_csv(visa_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
visa_df.head()
# Out:
#             Close
# Date
# 2015-03-03  68.83
# 2015-03-04  68.44
# 2015-03-05  68.53
# 2015-03-06  67.33
# 2015-03-09  67.86

# %%
# Reading data from 3rd stock

blackrock_data = Path("Resources/blackrock_historical.csv")
blackrock_df = pd.read_csv(blackrock_data, index_col="Date", infer_datetime_format=True, parse_dates=True)
blackrock_df.head()
# Out:
#              Close
# Date
# 2015-03-03  373.66
# 2015-03-04  369.14
# 2015-03-05  369.94
# 2015-03-06  365.47
# 2015-03-09  364.59

# %%
# Combine all stocks in a single DataFrame

my_stocks = pd.concat([visa_df, jpm_df, blackrock_df], axis='columns', join='inner')
my_stocks.head()
# Out:
#             Close  Close   Close
# Date
# 2015-03-03  68.83  61.97  373.66
# 2015-03-04  68.44  62.13  369.14
# 2015-03-05  68.53  62.00  369.94
# 2015-03-06  67.33  60.89  365.47
# 2015-03-09  67.86  61.50  364.59

# %%
# Reset Date index

# %%
# Reorganize portfolio data by having a column per symbol

my_stocks.columns = ['Visa', 'JPM', 'BlackRock']
my_stocks.head()
# Out:
#              Visa    JPM  BlackRock
# Date
# 2015-03-03  68.83  61.97     373.66
# 2015-03-04  68.44  62.13     369.14
# 2015-03-05  68.53  62.00     369.94
# 2015-03-06  67.33  60.89     365.47
# 2015-03-09  67.86  61.50     364.59

# %%
# Calculate daily returns

stocks_daily_returns = my_stocks.pct_change()

# Drop NAs

stocks_daily_returns = stocks_daily_returns.dropna()

# Display sample data
stocks_daily_returns.head()
# Out:
#                 Visa       JPM  BlackRock
# Date
# 2015-03-04 -0.005666  0.002582  -0.012097
# 2015-03-05  0.001315 -0.002092   0.002167
# 2015-03-06 -0.017511 -0.017903  -0.012083
# 2015-03-09  0.007872  0.010018  -0.002408
# 2015-03-10 -0.022989 -0.025041  -0.023040

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return

portfolio_returns = stocks_daily_returns.dot(weights)
cumulative_portfolio_returns = (1 + portfolio_returns).cumprod()

# Display sample data
# candidate_cumulative_returns.head()
cumulative_portfolio_returns.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame

combined_portfolio_returns = pd.concat([portfolio_returns, combined_returns], axis='columns', join='inner')

# combined_portfolio_returns = combined_portfolio_returns.rename(columns={'0': 'My Portfolio'})

combined_portfolio_returns.columns = ['My Portfolio', 'Soros Fund', 'Paulson & Co', 'Tiger Global', 'Berkshire Hathaway', 'Algo 1', 'Algo 2', 'S&P 500']

combined_portfolio_returns.head()
# Out:
#             My Portfolio  Soros Fund  Paulson & Co  Tiger Global  \
# Date
# 2015-03-04     -0.005060    0.002230      0.003241     -0.002534
# 2015-03-05      0.000463    0.004016      0.004076      0.002355
# 2015-03-06     -0.015832   -0.007905     -0.003574     -0.008481
# 2015-03-09      0.005161    0.000582      0.004225      0.005843
# 2015-03-10     -0.023690   -0.010263     -0.005341     -0.012079
#
#             Berkshire Hathaway    Algo 1    Algo 2   S&P 500
# Date
# 2015-03-04            0.004213 -0.008589  0.002416 -0.004389
# 2015-03-05            0.006726 -0.000955  0.004323  0.001196
# 2015-03-06           -0.013098 -0.004957 -0.011460 -0.014174
# 2015-03-09           -0.001652 -0.005447  0.001303  0.003944
# 2015-03-10           -0.009739 -0.001392 -0.012155 -0.016961

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)

# My data set was for the same timeframe so I did not need to do this step.  I just dropped nulls incase there were any. 


combined_portfolio_returns.dropna()

combined_portfolio_returns.head()
# Out:
#             My Portfolio  Soros Fund  Paulson & Co  Tiger Global  \
# Date
# 2015-03-04     -0.005060    0.002230      0.003241     -0.002534
# 2015-03-05      0.000463    0.004016      0.004076      0.002355
# 2015-03-06     -0.015832   -0.007905     -0.003574     -0.008481
# 2015-03-09      0.005161    0.000582      0.004225      0.005843
# 2015-03-10     -0.023690   -0.010263     -0.005341     -0.012079
#
#             Berkshire Hathaway    Algo 1    Algo 2   S&P 500
# Date
# 2015-03-04            0.004213 -0.008589  0.002416 -0.004389
# 2015-03-05            0.006726 -0.000955  0.004323  0.001196
# 2015-03-06           -0.013098 -0.004957 -0.011460 -0.014174
# 2015-03-09           -0.001652 -0.005447  0.001303  0.003944
# 2015-03-10           -0.009739 -0.001392 -0.012155 -0.016961

# %%
# Calculate cumulative returns of all portfolios

combined_portfolio_cumprod = (1 + combined_portfolio_returns).cumprod()

# Plot cumulative returns

combined_portfolio_cumprod.plot(figsize=(20,10))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Here we can see that My Portfolio produced a return of 80%, the 2nd hight of all the portfolios

# %%
combined_portfolio_cumprod.iloc[-1].sort_values(ascending=False)
# Out:
# Algo 1                1.938456
# My Portfolio          1.805362
# Berkshire Hathaway    1.563673
# S&P 500               1.391834
# Algo 2                1.270453
# Soros Fund            1.166043
# Tiger Global          0.861616
# Paulson & Co          0.783549
# Name: 2019-04-23 00:00:00, dtype: float64

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`

combined_std_2 = combined_portfolio_returns.std()
combined_std_2 = combined_std_2.sort_values(ascending=False)

annualized_std_2 = combined_std_2 * np.sqrt(252)
annualized_std_2 = annualized_std_2.sort_values(ascending=False)
annualized_std_2.head(10)
# Out:
# Berkshire Hathaway    0.205146
# My Portfolio          0.185107
# Tiger Global          0.173019
# S&P 500               0.135830
# Algo 2                0.132492
# Soros Fund            0.125393
# Algo 1                0.121018
# Paulson & Co          0.111517
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation

combined_portfolio_returns.rolling(window=21).std().plot(figsize=(20,10))


# Plot rolling standard deviation
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation

combined_portfolio_returns.plot(kind="scatter", y = "My Portfolio", x = "S&P 500", figsize = (20,10))
# Out:
# <AxesSubplot:xlabel='S&P 500', ylabel='My Portfolio'>

# %% [markdown]
# ### My Portfolio is highly correlated with the S&P 500.

# %%
# Calculate the correlation

correlation_2 = combined_portfolio_returns.corr()


# Display de correlation matrix

correlation_2.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_133b0_row0_col0, #T_133b0_row1_col1, #T_133b0_row2_col2, #T_133b0_row3_col3, #T_133b0_row4_col4, #T_133b0_row5_col5, #T_133b0_row6_col6, #T_133b0_row7_col7 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_133b0_row0_col1 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_133b0_row0_col2 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_133b0_row0_col3 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_133b0_row0_col4 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_133b0_row0_col5 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_133b0_row0_col6 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_133b0_row0_col7 {
#   background-color: #e46e56;
#   color: #f1f1f1;
# }
# #T_133b0_row1_col0 {
#   background-color: #f6bfa6;
#   color: #000000;
# }
# #T_133b0_row1_col2 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_133b0_row1_col3 {
#   background-color: #d6dce4;
# ...

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta

# 60-day rolling covariance of Soros Fund vs. S&P 500
rolling_covariance_myportfolio = combined_portfolio_returns['My Portfolio'].rolling(window=60).cov(combined_portfolio_returns['S&P 500'])


# 60-day rolling variance of S&P 500
rolling_variance_sp500 = combined_portfolio_returns['S&P 500'].rolling(window=60).var()


# 60-day rolling beta of Soros Fund and plot the data
rolling_beta_myportfolio = rolling_covariance_myportfolio / rolling_variance_sp500

# Plot the 60-day rolling trend
rolling_beta_myportfolio.plot(figsize=(20, 10), title='Rolling 60-Day Covariance of My Portfolio returns vs. S&P 500 Returns')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Covariance of My Portfolio returns vs. S&P 500 Returns'}, xlabel='Date'>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualzied Sharpe Ratios

# Assuming a risk free rate of 0.00022% daily, drawn from csv data in a prior activity.

risk_free_rate = 0.0000022

combined_sharpe_ratios_2 = ((combined_portfolio_returns.mean()-(risk_free_rate)) * 252) / (combined_portfolio_returns.std() * np.sqrt(252))

# %%
# Visualize the sharpe ratios as a bar plot

combined_sharpe_ratios_2.plot(kind = "bar", title = "Sharpe Ratios", figsize = (20,10))
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %% [markdown]
# <b>My Portfolio Analysis:</b><br>
# My Portfolio is a good portfolio for someone that has a high risk tolerance and is not also invested in other correlated portfolios like the S&P 500:
# * 2nd highest cumulative return among all the portfolios, and outperformed the S&P 500
# * 2nd highes sharpe ratio indicates a high reward to risk ratio per unit of volitility.
#
# My Portfolio is not a good portfolio with some that has a low risk tolerance and is already invested in the S&P 500:
# * 2nd highest standard deviation which implies that its high risk
# * High correlation to S&P 500, generally regarded as a negative if you are invested in the S&P 500 or other correlated portfolios; if one does poorly, they will probably all do poorly
